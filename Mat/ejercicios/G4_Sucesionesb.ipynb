# %%
from scipy.optimize import fsolve

try:
    import locale
    locale.setlocale(locale.LC_NUMERIC, 'es_CL.UTF-8')
except Exception as err:
    raise Exception("No se puede importar locale", err)

# %% [markdown]
# # Problema 1

# %% [markdown]
# Considere la sucesión $a_{n} = 3n^{2} + 7$. Por medio de un código en *Python* despliega en pantalla:
#
# 1. Los primeros $5$ términos.
# 2. Los $5$ términos que vienen inmediatamente después del decimoquinto término.

# %%
def sucesion_p1(t: int) -> int:
    return 3 * t ** 2 + 7

# %%
for termino in range(1, 6):
    print(f'El término {termino} es {sucesion_p1(termino)}')
# Out:
# El término 1 es 10
# El término 2 es 19
# El término 3 es 34
# El término 4 es 55
# El término 5 es 82

# %%
for termino in range(16, 21):
    print(f'El término {termino} es {sucesion_p1(termino):n}')
# Out:
# El término 16 es 775
# El término 17 es 874
# El término 18 es 979
# El término 19 es 1.090
# El término 20 es 1.207

# %% [markdown]
# # Problema 2

# %% [markdown]
# Considere la sucesión $g_{n} = 5n^{3}$. Implemente un código en *Python* que muestre en pantalla:
#
# 1. Los primeros $4$ términos de la sucesión.
# 2. Los $4$ términos que vienen inmediatamente después del octavo término.
# 3. Determinar si el término $40.000$ pertenece a la sucesión. Si es así, indicar en qué posición se encuentra.

# %%
def sucesion_p2(n: int) -> float:
    return 5 * n ** 3

# %%
for termino in range(1, 5):
    print(f"El valor del término {termino} es {sucesion_p2(termino):n}")
# Out:
# El valor del término 1 es 5
# El valor del término 2 es 40
# El valor del término 3 es 135
# El valor del término 4 es 320

# %%
for termino in range(9, 13):
    print(f"El valor del término {termino} es {sucesion_p2(termino):n}")
# Out:
# El valor del término 9 es 3.645
# El valor del término 10 es 5.000
# El valor del término 11 es 6.655
# El valor del término 12 es 8.640

# %%
res = fsolve(lambda t: sucesion_p2(t) - 40_000, 1)[0]
print(f"El resultado de fsolve es: {res:n}")
print(f"Pasamos {res} a la sucesión y obtenemos: {sucesion_p2(res):n}")
# Out:
# El resultado de fsolve es: 20
# Pasamos 20.0 a la sucesión y obtenemos: 40.000

# %% [markdown]
# # Problema 3

# %% [markdown]
# La sucesión de Fibonacci es una serie de números en la que cada número, desde el tercero en adelante, es la suma de los dos anteriores. Comienza con el $0$ y $1$, tal como se observa a continuación:
#
# $$0, 1, 1, 2, 3, 5, 8, 13, ...$$
#
# Formalmente, la sucesión se define de la siguiente manera:
#
# \begin{split}
# F(0) &= 0\\
# F(1) &= 1\\
# F(n) &= F(n - 1) + F(n - 2), \ \text{ para $n \geq 2$}
# \end{split}
#
# Esta sucesión se utiliza en una variedad de contextos en informática y algoritmos debido a sus propiedades matemáticas y patrones.
#
# 1. Implementa un código en *Python* que muestre en pantalla los primeros $20$ términos de la sucesión.
# 2. Calcula, utilizando un ciclo *for*, la suma de los primeros $30$ términos de la sucesión de Fibonacci.

# %%
def fibonacci(t: int) -> int:
    if t < 2:
        return t
    return fibonacci(t - 1) + fibonacci(t - 2)


def fibonacci_for(termino: int) -> int:
    if termino < 2:
        return termino

    actual = 0
    anterior = 1
    pre_anterior = 0
    for _ in range(2, termino + 1):
        actual = anterior + pre_anterior
        pre_anterior = anterior
        anterior = actual
    return actual

# %%
print("Secuencia Fibonacci:\n")
print("        \trecursivo\t   for")
for t in range (0, 20):
    print(f"Término {t+1}:\t{fibonacci(t):>5n}\t\t{fibonacci_for(t):>5n}")
# Out:
# Secuencia Fibonacci:
#
#         	recursivo	   for
# Término 1:	    0		    0
# Término 2:	    1		    1
# Término 3:	    1		    1
# Término 4:	    2		    2
# Término 5:	    3		    3
# Término 6:	    5		    5
# Término 7:	    8		    8
# Término 8:	   13		   13
# Término 9:	   21		   21
# Término 10:	   34		   34
# Término 11:	   55		   55
# Término 12:	   89		   89
# Término 13:	  144		  144
# Término 14:	  233		  233
# Término 15:	  377		  377
# Término 16:	  610		  610
# Término 17:	  987		  987
# Término 18:	1.597		1.597
# Término 19:	2.584		2.584
# Término 20:	4.181		4.181

# %%
res = sum([fibonacci(num) for num in range(0, 30)])
print(f"La suma de los primeros 30 términos es {res:n}")
# Out:
# La suma de los primeros 30 términos es 1.346.268

# %% [markdown]
# # Problema 4

# %% [markdown]
# Implementa un código que permita guardar en una lista la sucesión de los primeros $n$ números pares, con $n \geq 1$. Luego, determina:
#
# 1. ¿Cuál es el valor del décimo término?
# 2. Calcula, utilizando un ciclo *for*, la suma de los primeros $100$ números pares.
# 3. ¿En qué posición se encuentra el número $58$ dentro de la sucesión?

# %%
def sucesion_pares(termino: int) -> int:
    return 2 + 2 * (termino - 1)

# %%
print(f"El término 10 es: {sucesion_pares(10)}")
# Out:
# El término 10 es: 20

# %%
res = sum([sucesion_pares(t) for t in range(100 + 1)])
print(f"La suma de los primeros 100 números pares es: {res:n}")
# Out:
# La suma de los primeros 100 números pares es: 10.100

# %%
res = fsolve(lambda t: sucesion_pares(t) - 58, 1)[0]
print(f"El número que intersecta al 58 es: {res:n}")
print(f"Comprobamos pasando {res:n} a la sucesion: {sucesion_pares(res):n}")
# Out:
# El número que intersecta al 58 es: 29
# Comprobamos pasando 29 a la sucesion: 58

# %% [markdown]
# # Problema 5

# %% [markdown]
# Un nuevo software tiene $500$ usuarios y se espera que el número de usuarios crezca un $15\%$ respecto al mes anterior. Considere que $b_{n}$ es el número de usuarios transcurridos $n$ meses.
#
# 1. Calcula cuántos usuarios tendrá el software al cabo de tres meses. ¿Y al cabo de seis meses?
# 2. Mediante un código en *Pyhton* muestra la cantidad de usuarios que tendrá el software cada mes durante el primer año.
# 2. ¿Cuántos usuarios tendrá en total el software luego de un año? Utilice ciclos *for* para calcular.

# %%
def sucesion_usuarios(meses: int) -> int:
    return int((575) * (1.15 ** (meses - 1)))

# %%
mes = 3
res = sucesion_usuarios(mes)
print(f"Al cabo de {mes} meses el software tendrá {res:n} usuarios.")

mes = 6
res = sucesion_usuarios(mes)
print(f"Al cabo de {mes} meses el software tendrá {res:n} usuarios.")
# Out:
# Al cabo de 3 meses el software tendrá 760 usuarios.
# Al cabo de 6 meses el software tendrá 1.156 usuarios.

# %%
for mes in range(1, 13):
    print(f"Mes {mes}:\t{sucesion_usuarios(mes):>5n}")
# Out:
# Mes 1:	  575
# Mes 2:	  661
# Mes 3:	  760
# Mes 4:	  874
# Mes 5:	1.005
# Mes 6:	1.156
# Mes 7:	1.330
# Mes 8:	1.529
# Mes 9:	1.758
# Mes 10:	2.022
# Mes 11:	2.326
# Mes 12:	2.675

# %%
res = sucesion_usuarios(12)
print(f"La suma de usuarios al año es {res:n}.")
# Out:
# La suma de usuarios al año es 2.675.

# %% [markdown]
# # Problema 6

# %% [markdown]
# Un estudiante de ingeniería informática planea ahorrar para un proyecto personal. Para esto, el primer mes deposita en una cuenta $\$12.000$, el segundo mes deposita $\$14.000$ y así sucesivamente, de modo que cada mes aumenta el depósito en $\$2.000$. Considere que $a_{i}$ corresponde al depósito del estudiante en el mes $i$.
#
# 1. Implementa un código que permita mostrar en pantalla lo que depositó mensualmente durante el primer año.
# 2. ¿Cuánto depositó el estudiante en febrero del segundo año?
# 3. ¿Cuál será el total ahorrado al finalizar dos años?

# %%
def sucesion_deposito_mensual(mes: int) -> int:
    return 12_000 + 2_000 * (mes - 1)

# %%
for mes in range(1, 12 + 1):
    print(f"Mes {mes}:\t${sucesion_deposito_mensual(mes):n}")
# Out:
# Mes 1:	$12.000
# Mes 2:	$14.000
# Mes 3:	$16.000
# Mes 4:	$18.000
# Mes 5:	$20.000
# Mes 6:	$22.000
# Mes 7:	$24.000
# Mes 8:	$26.000
# Mes 9:	$28.000
# Mes 10:	$30.000
# Mes 11:	$32.000
# Mes 12:	$34.000

# %%
print(f"En febrero del segundo año depositó ${sucesion_deposito_mensual(14):n}")
# Out:
# En febrero del segundo año depositó $38.000

# %%
res = sum([sucesion_deposito_mensual(mes) for mes in range(1, 25)])
print(f"El total ahorrado al final de los 2 años es ${res:n}")
# Out:
# El total ahorrado al final de los 2 años es $840.000

# %% [markdown]
# # Problema 7

# %% [markdown]
# Por lo general, los proyectos son organizados en varias etapas que deben completarse secuencialmente.
#
# La fase inicial de un proyecto de software tiene una duración de $3$ meses y cada fase subsecuente reduce su duración en un $10 \%$ debido a la experiencia ganada. Determine:
#
# 1. ¿Cuánto dura la quinta fase?
# 2. Calcula la duración total del proyecto después de $10$ fases.

# %%
def secuencia_fases(fase: int) -> float:
    return 3 * 0.9 ** (fase - 1)

# %%
res = secuencia_fases(5)
print(f"La quinta fase dura: >{res:.2n} meses")
# Out:
# La quinta fase dura: 2 meses

# %%
detalle_fases = []
for fase_actual in range(1, 11):
    detalle_fases.append(secuencia_fases(fase_actual))

res = sum(detalle_fases)
print(f"La duración total del proyecto después de 10 fases es {res:.4n} meses.")
# Out:
# La duración total del proyecto después de 10 fases es 19,54 meses.

# %% [markdown]
# # Problema 8

# %% [markdown]
# En una sucesión aritmética, la diferencia entre un término y el anterior es $4$ y el décimo término es $-20$. Determine:
#
# 1. El primer término de la sucesión.
# 2. La expresión del término de lugar $n$.
# 3. Utilice un código en *Python* para calcular el término que ocupa el lugar $100$.
# 4. Determinar la posición del número $1.680$ en la secuencia. Calcule utilizando un ciclo *while*.

# %%
def sucesion_aritmetica_p8(termino: int) -> float:
    return -56 + 4 * (termino - 1)

# %%
print(f"El primer término de la sucesión es {sucesion_aritmetica_p8(1)}")
# Out:
# El primer término de la sucesión es -56

# %% [markdown]
# La expresión del término de lugar $n$ es:
#
# > $a_n = -56 + 4 (n - 1)$

# %%
print(f"El término que ocupa el lugar 100 es {sucesion_aritmetica_p8(100)}.")
# Out:
# El término que ocupa el lugar 100 es 340.

# %%
res = fsolve(lambda t: sucesion_aritmetica_p8(t) - 1680, 1)
print(f"La posición del número 1.680 es {res[0]:n}")
# Out:
# La posición del número 1.680 es 435

# %% [markdown]
# # Problema 9

# %% [markdown]
# El tercer término de una sucesión geométrica es $5$ y el sexto término es $40$. Determine:
#
# 1. La razón geométrica de la sucesión.
# 2. El primer término de la sucesión.
# 3. La expresión del término de lugar $n$.
# 4. Utilice un código en *Python* para calcular el término que ocupa el lugar $8$.
# 4. ¿Qué lugar ocupa en esta sucesión el término $20.480$? Calcule utilizando un ciclo *while*.

# %% [markdown]
# ### Respuestas
#
# 1.
#
# > Forma general:
# >
# > $a_n=a_1·r^{(n-1)}$
#
# > $a_m=a_n·r^{(m-n)}$
#
# Tenemos:
#
# $a_3=5$ y $a_6=40$
#
# Reemplazando:
#
# $a_6=a_3*r^{(6-3)}$
#
# $40=5*r^{(6-3)}$
#
# > $r=\sqrt[3]{8}$

# %%
print(f"La razón geométrica de la sucesión es {8**(1/3):n}")
# Out:
# La razón geométrica de la sucesión es 2

# %% [markdown]
# 2.
#
# El primer término de la sucesión es:
#
# $a_3=a_1*r^{3-1}$
#
# $a_1=a_3/r^2$
#
# Reemplazamos:
#
# $a_1=5/4$

# %% [markdown]
# 3.
#
# $a_n=5/4*2^{n-1}$

# %%
def sucesion_geometrica_p9(n: int) -> float:
    return 5 / 4 * 2 ** (n - 1)

# %%
print(f"El valor del octavo término es: {sucesion_geometrica_p9(8):n}")
# Out:
# El valor del octavo término es: 160

# %%
valor = 20_480
res = fsolve(lambda t: sucesion_geometrica_p9(t) - valor, 100)[0]
print(f"El término que cruza al punto {valor} es el: {res:n}")
# Out:
# El término que cruza al punto 20480 es el: 15

# %%
# Usando while
valor = 20_480
termino = 0
res = 0
encontrado = False

while res < valor:
    res = sucesion_geometrica_p9(termino)
    if res == valor:
        encontrado = True
        break
    termino += 1

if encontrado:
    print(f"El término que cruza al punto {valor} es el: {termino}")
else:
    print(f"El término no cruza al punto {valor}")
# Out:
# El término que cruza al punto 20480 es el: 15

# %% [markdown]
# # Problema 10

# %% [markdown]
# Una empresa de tecnología está optimizando sus servidores. Para ello mide las transacciones por segundo (TPS) de sus servidores en cada mes. Se ha obtenido que en el segundo mes, el rendimiento del servidor fue $1,2$ miles de TPS y en el quinto mes, el rendimiento fue $2,7$ miles de TPS. Si el número de TPS que hay mes a mes sigue una sucesión geométrica, determina utilizando un código en *Python*:
#
# 1. ¿Cuál es el rendimiento el noveno mes?
# 2. ¿En qué mes el rendimiento es de $23,4$ miles de TPS?
#
# Utilice dos decimales para el cálculo.

# %% [markdown]
# 1. Buscar la razón
#
# > Forma general:
# >
# > $a_n=a_1·r^{(n-1)}$
#
# $a_2=1.2$ tps \
# $a_5=2.7$ tps
#
# $a_5=a_2·r^{(5-2)}$
#
# $2.7/1.2=r^3$
#
# $r=\sqrt[3]{2.7/1.2}$

# %%
razon = (2.7/1.2) ** (1/3)
print(f"{razon:.2f}")
# Out:
# 1.31

# %% [markdown]
# Primer término:
#
# $1.2=a_1·(\sqrt[3]{2.7/1.2})$

# %%
res = 1.2/((2.7/1.2)**(1/3))
print(f"a1: {res:.2f}")
# Out:
# a1: 0.92

# %%
def rendimiento_servidor(mes: int | float) -> float:
    return 0.92 * 1.31 ** (mes - 1)

# %%
print(f"El rendimiento al noveno mes es: {rendimiento_servidor(9):.2f}")
# Out:
# El rendimiento al noveno mes es: 7.98

# %%
valor = 23.4
res = fsolve(lambda mes: rendimiento_servidor(mes) - valor, 10)[0]
print(f"El rendimiento del servidor será {valor} en el mes: {res:.4n}")
print(f"{rendimiento_servidor(12.98):.4n}")
# Out:
# El rendimiento del servidor será 23.4 en el mes: 12,98
# 23,37

# %% [markdown]
# # Problema 11

# %% [markdown]
# Una aplicación de redes sociales se estrenó el $1$ de enero con una cierta cantidad de usuarios. A partir de ahí, el número de usuarios nuevos de cada día fue siempre el mismo. El $3$ de enero tenía $500$ usuarios en total y el $10$ de enero tenía $1.501$ usuarios totales. Determine:
#
# 1. ¿Con cuántos usuarios comenzó a funcionar la aplicación?
# 2. ¿Cuántos usuarios tendrá la aplicación el $31$ de enero?
# 3. Si la aplicación tiene $5.505$ usuarios, ¿cuántos meses lleva funcionando?

# %% [markdown]
# > $a_n=a_1+d*(n-1)$
#
# - $a_3=500$
# - $a_{10}=1501$

# %% [markdown]
# $a_{10}=a_3+d(10-3)$
#
# $1501=500+7d$ \
# $d=1001/7$

# %%
print(f"El incremento es: {1001/7:n}")
# Out:
# El incremento es: 143

# %% [markdown]
# $a_1=500-(143*2)$ \
# $a_1=214$

# %%
def rrss_usuarios(dia: int | float) -> float:
    return 214 + 143 * (dia - 1)

# %%
print(f"El primer término de la sucesión es: {rrss_usuarios(1)}")
# Out:
# El primer término de la sucesión es: 214

# %%
print(f"El 31 de enero la aplicación tendrá {rrss_usuarios(31):n} usuarios.")
# Out:
# El 31 de enero la aplicación tendrá 4.504 usuarios.

# %%
valor = 5_505
res = fsolve(lambda dia: rrss_usuarios(dia) - valor, 35)[0]
print(f"La aplicación tendrá {valor:n} usuarios en {res:n} días.")

print(f"Comprobamos: {rrss_usuarios(res):n}.")
# Out:
# La aplicación tendrá 5.505 usuarios en 38 días.
# Comprobamos: 5.505.

# %% [markdown]
# # Problema 12

# %% [markdown]
# Una empresa de publicidad ofrece para un puesto de trabajo un salario inicial y un aumento mensual en una razón constante. Javier se presenta a la entrevista, y el encargado del departamento de recursos humanos le explica que en el segundo mes de trabajo su sueldo será de $\$402.000$, y que en el tercer mes de trabajo será de $\$404.010$. Determine:
#
# 1. El salario aproximado que Javier recibiría en el décimo mes de trabajo en la empresa.
# 2. ¿Cuál sería el ingreso total recibido por los sueldos de Javier durante el tercer año de trabajo?

# %% [markdown]
# > $a_n=a_1·r^{(n - 1)}$
#
# $a_2=\$402.000$ \
# $a_3=\$404.010$
#
# $a_3=a_2·r^{(3-2)}$ \
# $404.010=402.000*r^1$ \
# $1.005=r$
#
# $a_2=a_1*r$ \
# $402.000/1,005=a_1$

# %%
print(f"El primer término es: {402_000/1.005:.2f}")
# Out:
# El primer término es: 400000.00

# %%
def aumento_sueldo(mes: int | float) -> float:
    return 400_000 * 1.005 ** (mes - 1)

# %%
print(f"El salario aproximado al mes 10 es: ${aumento_sueldo(10):n}")
# Out:
# El salario aproximado al mes 10 es: $418.364

# %%
res = int(sum([aumento_sueldo(mes) for mes in range(24 + 2, 36 + 2)]))
print(f"El ingreso total recibido el tercer año de trabajo es: ${res:n}")
# Out:
# El ingreso total recibido el tercer año de trabajo es: $5.589.468

# %% [markdown]
# # Problema 13

# %% [markdown]
# Una empresa de ciberseguridad capacita trabajadores cada trimestre. En el primer trimestre capacitaron a $30$ trabajadores, en el segundo trimestre a $60$ trabajadores, y en el tercer trimestre a $120$ trabajadores. Si en los siguientes trimestres la empresa mantiene el mismo patrón de crecimiento, determine utilizando *Python*:
#
# 1. ¿A cuántos trabajadores capacitarán en el octavo trimestre?
# 2. Si la empresa lleva en el mercado $3$ años, ¿a cuántos trabajadores han capacitado en total?

# %% [markdown]
# > $a_n=a_1*r^{(n - 1)}$
#
# $a_1=30$ \
# $a_2=60$ \
# $a_3=120$
#
# > $r=2$

# %%
def crecimiento_capacitaciones(trimestre: int | float) -> float:
    return 30 * 2 ** (trimestre - 1)

# %%
print(f"El octavo mes se capacitarán: {crecimiento_capacitaciones(8):n}")
# Out:
# El octavo mes se capacitarán: 3.840

# %%
# 4 trimestres por año * 3 años = 12
res = sum([crecimiento_capacitaciones(trimestre) for trimestre in range(1, 12 + 1)])
print(f"Con 3 años en el mercado se habrán capacitado {res:n} trabajadores")
# Out:
# Con 3 años en el mercado se habrán capacitado 122.850 trabajadores

# %% [markdown]
# # Problema 14

# %% [markdown]
# Al llenar un tambor con agua, se registra que durante el minuto $4$ el tambor recibe $128$ litros, y durante el minuto $9$ recibe $88$ litros. Sabiendo que en cada minuto recibe una cantidad $d$ de litros de agua menos que en el minuto anterior, determine:
#
# 1. ¿En qué instante el tambor deja de recibir agua?
# 2. ¿Cuántos litros recibe en total el tambor?
#
# Realice los cálculos anteriores utilizando *Python*.

# %% [markdown]
# $a_n=a_1+d(n-1)$
#
# $a_4=128$ \
# $a_9=88$
#
# $a_9=a_4+d(9-4)$
#
# $88=128+5d$ \
# $d=(88-128)/5$

# %%
print(f"d = {(88-128)/5}")
# Out:
# d = -8.0

# %% [markdown]
# $128=a_1-8*(3)$ \
# $a_1=128+24$
#
# > $a_1=152$

# %%
def tambor_agua(minuto: int | float) -> float:
    return 152 + -8 * (minuto - 1)

# %%
res = fsolve(lambda min: tambor_agua(min), 10)[0]
print(f"El tambor dejará de recibir agua en {res:n} minutos")
# Out:
# El tambor dejará de recibir agua en 20 minutos

# %%
res = sum([tambor_agua(minuto) for minuto in range(1,20)])
print(f"El tambor recibirá en total {res:n} litros de agua.")
# Out:
# El tambor recibirá en total 1.520 litros de agua.
