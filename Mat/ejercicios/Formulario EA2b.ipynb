# %% [markdown]
# # Formulario Python Prueba 2 MAT2121

# %% [markdown]
# ## Importar bibliotecas o librerías

# %%
import numpy as np

# %% [markdown]
# ## Sucesiones

# %% [markdown]
# Término general de una sucesión aritmética:
#
# $$a_{n} = a_{1} + d\cdot(n - 1)$$
#
# Término general de una sucesión geométrica:
#
# $$a_{n} = a_{1} \cdot r^{n-1}$$

# %%
#Encontrar el termino de la sucesión en la posición n
sucesion = []
for i in range(cantidad de términos a mostrar):
    n = i + 1
    sucesion.append(Término general)
    if n==numero: #reemplazar la posición en "numero"
        print(f'El término {n} es {sucesion[i]}')

# %%
#Creación de sucesiones con listas
sucesion = []
for i in range(cantidad de términos a mostrar):
    n = i + 1
    sucesion.append(Término general)
    print(f'El término {n} es {sucesion[i]}')

# %%
#Suma de términos de una lista
sucesion = []
for i in range(cantidad de términos a mostrar):
    n = i + 1
    sucesion.append(Término general)
    print(f'El término {n} es {sucesion[i]}')
suma = sum(sucesion)
print(f'La suma de los primeros términos de la sucesión es {suma}.')

# %%
#Determinar si un determinado valor es término de la sucesión.
final=VALOR #indicamos el VALOR a encontrar
termino=0
n=0
dif=final-termino
while dif>0:
    n +=1
    termino=TÉRMINO GENERAL DE LA SUCESIÓN #escribir la sucesión
    dif=final-termino

if dif==0:
    print(f'El {final} es un término de la sucesión y ocupa el lugar {n}')

else:
    print(f'El {final} no pertenece a la sucesión')

# %% [markdown]
# ## Matrices y aplicaciones

# %%
#Definición de matrices en Python
A = np.array([[elemento, elemento],
              [elemento, elemento]])

B = np.array([[elemento, elemento],
              [elemento, elemento]])


#Transpuesta de una matriz
T = B.T

#Multiplicación de matrices
C = np.dot(A, B)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Definición de matrices en Python
# ----> 2 A = np.array([[elemento, elemento],
#       3               [elemento, elemento]])
#       5 B = np.array([[elemento, elemento],
#       6               [elemento, elemento]])
#       9 #Transpuesta de una matriz
#
# NameError: name 'np' is not defined

# %%
#Cración de matrices mediante función sobre los índices

D = np.fromfunction(lambda i, j: función sobre los índices, (orden de la matriz))
E = np.fromfunction(lambda i, j: función sobre los índices, (orden de la matriz))

# %%
#Inversa de una matriz

F = np.array([[elemento, elemento],
              [elemento, elemento]])

F_inv = np.linalg.inv(F)
